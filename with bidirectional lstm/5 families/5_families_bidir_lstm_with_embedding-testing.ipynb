# %%
import sys
sys.path.insert(1, '..\\..\\')

import os
import data_loader
from numpy import trapz
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, LSTM, Dropout, Embedding, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Tensorflow Version

# %%
print(tf.__version__)
# Out:
# 2.3.1

# %% [markdown]
# ### Global Variables

# %%
malware_data_dir = '../../data/'
saved_model_path = 'saved_model/'
opcode_to_int_path = "opcodeToInt.txt"
num_unique_opcodes = 30
max_opcode_sequence_length = 2000
embed_vector_length = 128
num_lstm_unit = 16
dropout_amt = 0.3
batch_size = 32
num_epochs = 100
test_size= 0.15       # reserve for testing
num_families_to_use = 5

shutdown = False

# %% [markdown]
# ### Load the Data

# %%
raw_train_data = data_loader.getTrainData(malware_data_dir, 
                                          num_families_to_use, 
                                          num_unique_opcodes, 
                                          max_opcode_sequence_length, 
                                          opcode_to_int_path)
# Out:
# Getting list of paths to training data
# {'winwebsec': 6862260, 'vundo': 3492760, 'zbot': 3256944, 'hotbar': 2952000, 'renos': 2612858}
# Loading training data for hotbar
# Loading training data for renos
# Loading training data for vundo
# Loading training data for winwebsec
# Loading training data for zbot
# All training data loaded

# %% [markdown]
# ### Data preprocessing

# %%
family_names = list(raw_train_data.keys())
print(family_names)

# Split opcode family data in individual lists
train_data = list()
for family, data in raw_train_data.items():
    train_data.append(data)
    
# Pad training data to ensure uniformity
padded_train_data = list()
for family_opcodes in train_data:
    padded_sequence = pad_sequences(family_opcodes, 
                                    maxlen=max_opcode_sequence_length)
    padded_train_data.append(padded_sequence)
    
# Concatenate all training data into 1 long list instead of multiple lists
train_data_raw = np.concatenate(padded_train_data)

print(len(train_data))
# Out:
# ['hotbar', 'renos', 'vundo', 'winwebsec', 'zbot']
# 5

# %% [markdown]
# ### Make the labels

# %%
train_labels = []

for count, data in enumerate(padded_train_data):
    labels_list = np.full(shape=(len(data)), fill_value=count)
    train_labels.append(labels_list)

train_labels_raw = np.concatenate(train_labels)

# %% [markdown]
# ### Split into training and testing sets

# %%
def split_data(train_data_raw, train_labels_raw):
    # Split into training and testing data
    train_data, test_data, train_labels, test_labels = train_test_split(train_data_raw, train_labels_raw, test_size=test_size)

    # Make divisible by batch size
    num_data_train = int(len(train_data)/batch_size) * batch_size
    num_data_test = int(len(test_data)/batch_size) * batch_size

    train_data = train_data[:num_data_train]
    train_labels = train_labels[:num_data_train]
    test_data = test_data[:num_data_test]
    test_labels = test_labels[:num_data_test]
    
#     print("train_data shape: {}".format(train_data.shape))
#     print("test_data shape: {}".format(test_data.shape))
#     print("train_labels shape: {}".format(train_labels.shape))
#     print("test_labels shape: {}".format(test_labels.shape))
    
    return train_data, test_data, train_labels, test_labels

# %% [markdown]
# ### Make the Model

# %%
def create_model():
    model = Sequential()
    model.add(Input(batch_shape=(batch_size, max_opcode_sequence_length), name="input"))
    model.add(Embedding(input_dim=num_unique_opcodes+1,
                        output_dim=embed_vector_length,
                        input_length=max_opcode_sequence_length, name="embedding"))
    
    model.add(Bidirectional(LSTM(num_lstm_unit), input_shape=(None, max_opcode_sequence_length)))
    model.add(Dense(512, activation='sigmoid', name='dense1'))
    model.add(Dense(128, activation='sigmoid', name='dense2'))
    model.add(Dense(32, activation='sigmoid', name='dense3'))
    model.add(Dense(num_families_to_use, activation='softmax', name="output"))
    optimizer = Adam()
    model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    model.summary()
    
    return model

# %%
results = []

for i in range(5):
    # get train and test data
    train_data, test_data, train_labels, test_labels = split_data(train_data_raw, train_labels_raw)
    
    # train model
    model_train = create_model()
    early_stopping = EarlyStopping(monitor='loss', verbose=1, patience=2)
    history = model_train.fit(x=train_data,
                          y=train_labels,
                          batch_size=batch_size,
                          callbacks = [early_stopping],
                          epochs=num_epochs,)
    
    # evaluate
    model_evaluate = create_model()
    model_evaluate.set_weights(model_train.get_weights())

    scores = model_evaluate.evaluate(test_data, test_labels, verbose=0, callbacks = [early_stopping])
    accuracy = scores[1]*100
    print(accuracy)
    results.append(accuracy)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_7 (Bidirection (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 265/265 [==============================] - 30s 115ms/step - loss: 1.1728 - accuracy: 0.5288
# Epoch 2/100
# 265/265 [==============================] - 31s 115ms/step - loss: 0.7021 - accuracy: 0.7722
# Epoch 3/100
# 265/265 [==============================] - 30s 115ms/step - loss: 0.5454 - accuracy: 0.8232
# Epoch 4/100
# 265/265 [==============================] - 31s 116ms/step - loss: 0.4793 - accuracy: 0.8341
# Epoch 5/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.4517 - accuracy: 0.8454
# Epoch 6/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.3864 - accuracy: 0.8704
# Epoch 7/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.3492 - accuracy: 0.8825
# Epoch 8/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.3216 - accuracy: 0.8933
# Epoch 9/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.3071 - accuracy: 0.8966
# Epoch 10/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.3063 - accuracy: 0.8938
# Epoch 11/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.3418 - accuracy: 0.8632
# Epoch 12/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2966 - accuracy: 0.8969
# Epoch 13/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2722 - accuracy: 0.9067
# Epoch 14/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.2797 - accuracy: 0.9042
# Epoch 15/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2450 - accuracy: 0.9171
# Epoch 16/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2147 - accuracy: 0.9274
# Epoch 17/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2036 - accuracy: 0.9328
# Epoch 18/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2018 - accuracy: 0.9344
# Epoch 19/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1963 - accuracy: 0.9371
# Epoch 20/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1854 - accuracy: 0.9363
# Epoch 21/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1902 - accuracy: 0.9364
# Epoch 22/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1820 - accuracy: 0.9351
# Epoch 23/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1636 - accuracy: 0.9469
# Epoch 24/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1468 - accuracy: 0.9513
# Epoch 25/100
# 265/265 [==============================] - 30s 115ms/step - loss: 0.1388 - accuracy: 0.9545
# Epoch 26/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.1334 - accuracy: 0.9540
# Epoch 27/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.1430 - accuracy: 0.9526
# Epoch 28/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1337 - accuracy: 0.9537
# Epoch 00028: early stopping
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_8 (Bidirection (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# 93.9538061618805
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_9 (Bidirection (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 265/265 [==============================] - 32s 121ms/step - loss: 1.1647 - accuracy: 0.5165
# Epoch 2/100
# 265/265 [==============================] - 32s 121ms/step - loss: 0.7210 - accuracy: 0.7445
# Epoch 3/100
# 265/265 [==============================] - 32s 121ms/step - loss: 0.5817 - accuracy: 0.8032
# Epoch 4/100
# 265/265 [==============================] - 31s 118ms/step - loss: 0.4936 - accuracy: 0.8388
# Epoch 5/100
# 265/265 [==============================] - 31s 118ms/step - loss: 0.5523 - accuracy: 0.8026
# Epoch 6/100
# 265/265 [==============================] - 31s 118ms/step - loss: 0.4636 - accuracy: 0.8396
# Epoch 7/100
# 265/265 [==============================] - 31s 118ms/step - loss: 0.4156 - accuracy: 0.8587
# Epoch 8/100
# 265/265 [==============================] - 31s 118ms/step - loss: 0.4532 - accuracy: 0.8445
# Epoch 9/100
# 265/265 [==============================] - 31s 119ms/step - loss: 0.3823 - accuracy: 0.8721
# Epoch 10/100
# 265/265 [==============================] - 32s 120ms/step - loss: 0.3890 - accuracy: 0.8769
# Epoch 11/100
# 265/265 [==============================] - 31s 119ms/step - loss: 0.3310 - accuracy: 0.8989
# Epoch 12/100
# 265/265 [==============================] - 32s 119ms/step - loss: 0.2983 - accuracy: 0.9123
# Epoch 13/100
# 265/265 [==============================] - 32s 120ms/step - loss: 0.2724 - accuracy: 0.9179
# Epoch 14/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.2584 - accuracy: 0.9210
# Epoch 15/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.2558 - accuracy: 0.9208
# Epoch 16/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2429 - accuracy: 0.9259
# Epoch 17/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2380 - accuracy: 0.9245
# Epoch 18/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2367 - accuracy: 0.9236
# Epoch 19/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2185 - accuracy: 0.9310
# Epoch 20/100
# 265/265 [==============================] - 31s 116ms/step - loss: 0.2029 - accuracy: 0.9401
# Epoch 21/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1992 - accuracy: 0.9388
# Epoch 22/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.1931 - accuracy: 0.9401
# Epoch 23/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1870 - accuracy: 0.9412
# Epoch 24/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.1784 - accuracy: 0.9440
# Epoch 25/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.1749 - accuracy: 0.9436
# Epoch 26/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.2118 - accuracy: 0.9298
# Epoch 27/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.1990 - accuracy: 0.9355
# Epoch 00027: early stopping
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_10 (Bidirectio (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# 93.2744562625885
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_11 (Bidirectio (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 265/265 [==============================] - 30s 114ms/step - loss: 1.1875 - accuracy: 0.5100
# Epoch 2/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.7642 - accuracy: 0.7350
# Epoch 3/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.6046 - accuracy: 0.8077
# Epoch 4/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.5429 - accuracy: 0.8292
# Epoch 5/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.5083 - accuracy: 0.8404
# Epoch 6/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.4585 - accuracy: 0.8542
# Epoch 7/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.4150 - accuracy: 0.8680
# Epoch 8/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.3821 - accuracy: 0.8843
# Epoch 9/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.3616 - accuracy: 0.8889
# Epoch 10/100
# 265/265 [==============================] - 31s 117ms/step - loss: 0.3396 - accuracy: 0.8965
# Epoch 11/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.3244 - accuracy: 0.8994
# Epoch 12/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.3063 - accuracy: 0.9050
# Epoch 13/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.2809 - accuracy: 0.9096
# Epoch 14/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.2775 - accuracy: 0.9112
# Epoch 15/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.2377 - accuracy: 0.9271
# Epoch 16/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.2231 - accuracy: 0.9335
# Epoch 17/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.2088 - accuracy: 0.9379
# Epoch 18/100
# 265/265 [==============================] - 31s 118ms/step - loss: 0.2062 - accuracy: 0.9393
# Epoch 19/100
# 265/265 [==============================] - 31s 117ms/step - loss: 0.1946 - accuracy: 0.9413
# Epoch 20/100
# 265/265 [==============================] - 31s 117ms/step - loss: 0.1910 - accuracy: 0.9422
# Epoch 21/100
# 265/265 [==============================] - 30s 114ms/step - loss: 0.2151 - accuracy: 0.9303
# Epoch 22/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1881 - accuracy: 0.9420
# Epoch 23/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1955 - accuracy: 0.9395
# Epoch 24/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1681 - accuracy: 0.9463
# Epoch 25/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1594 - accuracy: 0.9493
# Epoch 26/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1552 - accuracy: 0.9507
# Epoch 27/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1493 - accuracy: 0.9518
# Epoch 28/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1620 - accuracy: 0.9488
# Epoch 29/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1470 - accuracy: 0.9535
# Epoch 30/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1387 - accuracy: 0.9571
# Epoch 31/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1323 - accuracy: 0.9580
# Epoch 32/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1300 - accuracy: 0.9594
# Epoch 33/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1242 - accuracy: 0.9607
# Epoch 34/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1281 - accuracy: 0.9605
# Epoch 35/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1201 - accuracy: 0.9619
# Epoch 36/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1142 - accuracy: 0.9645
# Epoch 37/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1050 - accuracy: 0.9662
# Epoch 38/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1077 - accuracy: 0.9672
# Epoch 39/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1103 - accuracy: 0.9672
# Epoch 00039: early stopping
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_12 (Bidirectio (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# 94.4972813129425
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_13 (Bidirectio (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 265/265 [==============================] - 30s 113ms/step - loss: 1.2029 - accuracy: 0.5053
# Epoch 2/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.7342 - accuracy: 0.7229
# Epoch 3/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.6474 - accuracy: 0.7415
# Epoch 4/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.5523 - accuracy: 0.7791
# Epoch 5/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.5552 - accuracy: 0.7867
# Epoch 6/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.4211 - accuracy: 0.8529
# Epoch 7/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.3330 - accuracy: 0.8870
# Epoch 8/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2980 - accuracy: 0.9015
# Epoch 9/100
# 265/265 [==============================] - 32s 122ms/step - loss: 0.2558 - accuracy: 0.9198
# Epoch 10/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2314 - accuracy: 0.9236
# Epoch 11/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2213 - accuracy: 0.9309
# Epoch 12/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2011 - accuracy: 0.9358
# Epoch 13/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.1944 - accuracy: 0.9374
# Epoch 14/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.2448 - accuracy: 0.9179
# Epoch 15/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2033 - accuracy: 0.9329
# Epoch 00015: early stopping
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_14 (Bidirectio (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# 91.847825050354
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_15 (Bidirectio (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 265/265 [==============================] - 30s 113ms/step - loss: 1.2585 - accuracy: 0.4866
# Epoch 2/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.8176 - accuracy: 0.6935
# Epoch 3/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.6444 - accuracy: 0.7644
# Epoch 4/100
# 265/265 [==============================] - 30s 113ms/step - loss: 0.5349 - accuracy: 0.8123
# Epoch 5/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.4751 - accuracy: 0.8394
# Epoch 6/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.3969 - accuracy: 0.8696
# Epoch 7/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.3533 - accuracy: 0.8866
# Epoch 8/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.3481 - accuracy: 0.8815
# Epoch 9/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.3043 - accuracy: 0.8986
# Epoch 10/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2726 - accuracy: 0.9112
# Epoch 11/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2482 - accuracy: 0.9212
# Epoch 12/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2269 - accuracy: 0.9246
# Epoch 13/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2086 - accuracy: 0.9302
# Epoch 14/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1956 - accuracy: 0.9331
# Epoch 15/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1906 - accuracy: 0.9367
# Epoch 16/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1925 - accuracy: 0.9349
# Epoch 17/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.1817 - accuracy: 0.9386
# Epoch 18/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2238 - accuracy: 0.9281
# Epoch 19/100
# 265/265 [==============================] - 30s 112ms/step - loss: 0.2168 - accuracy: 0.9282
# Epoch 00019: early stopping
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (32, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_16 (Bidirectio (32, 32)                  18560
# _________________________________________________________________
# dense1 (Dense)               (32, 512)                 16896
# _________________________________________________________________
# dense2 (Dense)               (32, 128)                 65664
# _________________________________________________________________
# dense3 (Dense)               (32, 32)                  4128
# _________________________________________________________________
# output (Dense)               (32, 5)                   165
# =================================================================
# Total params: 109,381
# Trainable params: 109,381
# Non-trainable params: 0
# _________________________________________________________________
# 90.55706262588501

# %%
for x in results:
    print(x)

# model_train.save_weights(saved_model_path)
# Out:
# 93.9538061618805
# 93.2744562625885
# 94.4972813129425
# 91.847825050354
# 90.55706262588501

# %% [markdown]
# ### Use History to plot and accuracy throughout training

# %%
history.history

# %% [markdown]
# ### Evaluate Model

# %%
model_evaluate = create_model()
model_evaluate.set_weights(model_train.get_weights())

scores = model_evaluate.evaluate(test_set, test_labels, verbose=0, callbacks=[callback])
accuracy = scores[1]*100
print("Accuracy: %0.2f%%" % (scores[1]*100))
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (64, 2000, 128)           3968
# _________________________________________________________________
# bidirectional_4 (Bidirection (64, 128)                 98816
# _________________________________________________________________
# dense (Dense)                (64, 5)                   645
# =================================================================
# Total params: 103,429
# Trainable params: 103,429
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Model was constructed with shape (64, 2000) for input Tensor("input_7:0", shape=(64, 2000), dtype=float32), but it was called on an input with incompatible shape (32, 2000).
# WARNING:tensorflow:Model was constructed with shape (64, 2000) for input Tensor("input_7:0", shape=(64, 2000), dtype=float32), but it was called on an input with incompatible shape (32, 2000).
# Accuracy: 89.69%

# %% [markdown]
# ### Load Model From Save and Evaluate

# %%
model = create_model()
model.load_weights(saved_model_path)

# %%
scores = model.evaluate(test_set, test_labels, verbose=0)
accuracy = scores[1]*100
print("Accuracy: %0.2f%%" % (scores[1]*100))

# %% [markdown]
# ## Make ROC Curve

# %% [markdown]
# ### Make scatter plot

# %%
# separate winwebsec and zbot test data
winwebsec_test_data = []
zbot_test_data = []

for i in range(len(test_labels)):
    if test_labels[i] == 0:
        winwebsec_test_data.append(test_set[i])
    else:
        zbot_test_data.append(test_set[i])
        
winwebsec_test_data = np.asarray(winwebsec_test_data[:192])
zbot_test_data = np.asarray(zbot_test_data[:128])

# %%
print(winwebsec_test_data.shape)
print(zbot_test_data.shape)


winwebsecY = model.predict(winwebsec_test_data)
winwebsecX = [i+1 for i in range(len(winwebsec_test_data))]

zbotY = model.predict(zbot_test_data)
zbotX = [i+1 for i in range(len(zbot_test_data))]

# %%
plt.figure(100)
f = plt.scatter(winwebsecX, winwebsecY, marker='o',
                c='darkblue', s=30, label="winwebsec")
plt.scatter(zbotX, zbotY, marker='o', c='red', s=30, label="zbot")
plt.title("Winwebsec vs. Zbot LSTM Prediction Scatter Plot",
          fontsize=18, wrap=True)
f.axes.get_xaxis().set_visible(False)
plt.ylabel("Prediction", fontsize=15)
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', fontsize=12)

# %% [markdown]
# ### Make ROC Curve

# %%
def sortByFirstItem(item):
    return item[0]

# %%
winwebsecROC = [(data, "winwebsec") for data in winwebsecY]
zbotROC = [(data, "zbot") for data in zbotY]

zbotROC.sort(key=sortByFirstItem)
winwebsecROC.sort(key=sortByFirstItem)

dataROC = zbotROC + winwebsecROC
dataROC.sort(key=sortByFirstItem, reverse=True)

# %%
def calculate_TPR_FPR(thresholdLine, dataROC):
    TP = 0
    FN = 0
    TN = 0
    FP = 0

    for data in dataROC:
        yVal = data[0]
        family = data[1]

        if family == "winwebsec":
            if yVal < thresholdLine:
                TP += 1
            else:
                FN += 1
        elif family == "zbot":
            if yVal > thresholdLine:
                TN += 1
            else:
                FP += 1
    TPR = TP/(TP+FN)
    FPR = 1 - (TN/(TN+FP))

    return TPR, FPR

# %%
def calculateAUC(rocData):
    sum = 0

    # initialization
    prevX = -1
    prevY = -1

    for points in rocData:
        curX = points[0]
        curY = points[1]

        # Skip for first point
        if prevX != -1 and prevY != -1:
            # check if rectangle
            if prevY == curY:
                sum += abs(curX - prevX) * prevY
            # check if trapezoid
            else:
                sum += (curY + prevY) * abs(curX - prevX) * 0.5

        prevX = curX
        prevY = curY

    return sum

# %%
rocX = list()  # used to plot
rocY = list()  # used to plot
rocData = list()    # used to calculate AUC

for entry in dataROC:
    thresholdLine = entry[0]
    TPR, FPR = calculate_TPR_FPR(thresholdLine, dataROC)

    rocX.append(FPR)
    rocY.append(TPR)
    rocData.append([FPR, TPR])

rocData.sort(key=lambda item: (item[0], item[1]), reverse=True)

AUC = round(calculateAUC(rocData), 3)

# %%
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

plt.figure(200)
plt.plot(rocX, rocY, marker=".", markersize=8)
plt.title("Winwebsec vs. Zbot LSTM Log Probability ROC", fontsize=18)
plt.xlabel("FPR", fontsize=15)
plt.ylabel("TPR", fontsize=15)
plt.grid()
plt.text(x=0.75, y=0, s="AUC: {0}".format(AUC), fontsize=14, bbox=props)

# show plots
plt.show()

# %%
if shutdown:
    os.system('shutdown -s')
